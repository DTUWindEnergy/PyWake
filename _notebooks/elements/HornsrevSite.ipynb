# %% [markdown]
# # Hornsrev1 example site

# %%
import numpy as np
import matplotlib.pyplot as plt
from py_wake.examples.data.hornsrev1 import HornsrevSite

site = HornsrevSite()

# %% [markdown]
# HornsrevSite is a `UniformWeibullSite`, see documentation [here]()

# %%
site.plot_wd_distribution(n_wd=16, ws_bins=[0,5,10,15,20,25])

# %%
site.plot_ws_distribution(wd=[0,90,180,270])

# %%
site.plot_ws_distribution(wd=[0,90,180,270], include_wd_distribution=True)

# %% [markdown]
# The wt object is a [`OneTypeWindTurbines`](../docs/build/html/_src_docs/wind_turbines/OneTypeOnlyWindTurbines.html) object which is a subclass of the [`WindTurbines`](../docs/build/html/_src_docs/wind_turbines/WindTurbines.html) class.
